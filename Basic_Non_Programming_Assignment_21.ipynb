# %% [markdown]
# # ASSIGNMENT 21

# %% [markdown]
# 1. Add the current date to the text file today.txt as a string.

# %%
import datetime
from datetime import date
now = date.today()
cur_date = now.isoformat()
cur_date
# Out:
# '2022-01-30'

# %%
with open('today.txt','w') as file:
    file.write(cur_date)

# %% [markdown]
# 2. Read the text file today.txt into the string today_string

# %%
with open('today.txt','r') as file:
    today_string = file.read()
today_string
# Out:
# '2022-01-30'

# %% [markdown]
# 3. Parse the date from today_string.

# %%
from datetime import datetime
format = '%Y-%m-%d'
datetime.strptime(today_string,format)
# Out:
# datetime.datetime(2022, 1, 30, 0, 0)

# %% [markdown]
# 4. List the files in your current directory

# %%
import os
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'Assignment_1.docx',
#  'Assignment_10.docx',
#  'Assignment_11.docx',
#  'Assignment_12.docx',
#  'Assignment_13.docx',
#  'Assignment_14.docx',
#  'Assignment_15.docx',
#  'Assignment_16.docx',
#  'Assignment_17.docx',
#  'Assignment_18.docx',
#  'Assignment_19.docx',
#  'Assignment_2.docx',
#  'Assignment_20.docx',
#  'Assignment_21.docx',
#  'Assignment_22.docx',
#  'Assignment_23.docx',
#  'Assignment_24.docx',
#  'Assignment_25.docx',
#  'Assignment_3.docx',
#  'Assignment_4.docx',
#  'Assignment_5.docx',
#  'Assignment_6.docx',
#  'Assignment_7.docx',
#  'Assignment_8.docx',
#  'Assignment_9.docx',
#  'Basic_Non_Programming_Assignment_1.ipynb',
#  'Basic_Non_Programming_Assignment_10.ipynb',
#  'Basic_Non_Programming_Assignment_2.ipynb',
#  'Basic_Non_Programming_Assignment_3.ipynb',
#  'Basic_Non_Programming_Assignment_4.ipynb',
#  'Basic_Non_Programming_Assignment_5.ipynb',
#  'Basic_Non_Programming_Assignment_6.ipynb',
#  'Basic_Non_Programming_Assignment_7.ipynb',
#  'Basic_Non_Programming_Assignment_8.ipynb',
#  'Basic_Non_Programming_Assignment_9.ipynb',
#  'books.csv',
#  'books.db',
#  'file1.txt',
#  'file2.txt',
#  'mydata.bak',
#  'mydata.dat',
#  'mydata.dir',
#  'New Microsoft PowerPoint Presentation.pptx',
#  'programLog.txt',
#  'Table1.docx',
#  'test.txt',
#  'Test1',
#  'Test1 - Copy',
#  'today.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'Upload',
#  'Zoo.py',
#  '__pycache__']

# %% [markdown]
# 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
os.listdir('..')
# Out:
# ['Advance_Non_Programming',
#  'Advance_Programming',
#  'Basic_Non_Programming',
#  'Basic_Programming',
#  'Computer_Vision_Assignment',
#  'Deep_Learning',
#  'DL_And_CV',
#  'Excel',
#  'ML',
#  'NLP',
#  'PowerBI',
#  'Python',
#  'SQL',
#  'Statistics']

# %% [markdown]
# 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing

def printsec(seconds):
    from datetime import datetime
    from time import sleep
    sleep(seconds)
    print('wait', seconds, 'seconds, time is', datetime.utcnow())
    
if __name__ == '__main__':
    import random    
    for n in range(3):
        seconds = random.random()
        proc = multiprocessing.Process(target=printsec, args=(seconds,))
        proc.start()

# %%
# !python multi.py
# Out:
# wait 0.19326047171913252 seconds, time is 2022-01-30 11:44:39.710111
# wait 0.2907739704235568 seconds, time is 2022-01-30 11:44:39.803098
# wait 0.4304031695816041 seconds, time is 2022-01-30 11:44:39.943516

# %% [markdown]
# 7. Create a date object of your day of birth.

# %%
my_date = date(1982,9,25)
my_date
# Out:
# datetime.date(1982, 9, 25)

# %% [markdown]
# 8. What day of the week was your day of birth?

# %%
my_date.weekday()
# Out:
# 5

# %% [markdown]
# 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import timedelta
day10000 = my_date + timedelta(days=10000)
day10000
# Out:
# datetime.date(2010, 2, 10)
